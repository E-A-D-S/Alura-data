# %% [markdown]
# <a href="https://colab.research.google.com/github/E-A-D-S/Imersao-dados-Alura/blob/main/Exerc%C3%ADcios%20Aula1_alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10)
# Out:
#                                Rua                Bairro     Cidade  Metragem  \
# 2530                      Rua Tefé                Sumaré  São Paulo       452
# 5621        Rua Montanaro Canavese          Cidade Líder  São Paulo       150
# 1821                           NaN         Jardim Europa  São Paulo      1301
# 2986           Rua Francisco Farel  Jardim das Bandeiras  São Paulo       315
# 6919                           NaN      Jardim Aeroporto  São Paulo       152
# 2430              Rua Acruás, 188         Vila Congonhas  São Paulo       158
# 5493             Rua Oliveira Lima               Cambuci  São Paulo       140
# 7391  Rua Sílvia Celeste de Campos     Alto de Pinheiros  São Paulo       670
# 7509          Rua Armando Brussolo           Vila Romana  São Paulo       254
# 9034               Rua Camé, , 74                  Mooca  São Paulo       440
#
#       Quartos  Banheiros  Vagas          Valor
# 2530        3          4      2   R$ 2.300.000
# ...

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados["Bairro"][10003]
# Out:
# 'Vila Sofia'

# %%
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
sum(dados["Bairro"] == "Vila Mariana")*1
# Out:
# 184

# %%
tem_imoveis_vila = dados["Bairro"] == "Vila Mariana"
tem_imoveis_vila
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
imoveis_vila_mariana = dados[tem_imoveis_vila]

# %%
imoveis_vila_mariana["Metragem"].mean()
# Out:
# 233.6195652173913

# %%
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
numero_imoveis_bairro = dados["Bairro"].value_counts()
numero_imoveis_bairro.head(10).plot.bar()

# %% [markdown]
# #Exercício 1

# %%
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
# existem 701 bairros onde precisamos agrupar e fazer então as médias de todos
dados[['Bairro', 'Metragem']].groupby('Bairro').mean()
# Out:
#                      Metragem
# Bairro
# Aclimação          253.056818
# Alto da Boa Vista  418.875000
# Alto da Lapa       294.337209
# Alto da Mooca      270.050000
# Alto de Pinheiros  433.444988
# ...                       ...
# Vila Água Funda    152.200000
# Água Branca        191.000000
# Água Fria          165.416667
# Água Funda         139.000000
# Água Rasa          340.250000
#
# [701 rows x 1 columns]

# %% [markdown]
# #Exercício 2

# %%
# Fazendo a seleção por um bairro
dados[dados['Bairro'] == 'Pacaembu']
# Out:
#                                        Rua    Bairro     Cidade  Metragem  \
# 267                                    NaN  Pacaembu  São Paulo       306
# 293    Rua José de Freitas Guimarães, 353   Pacaembu  São Paulo       400
# 297              Rua Cássio Martins Vilaça  Pacaembu  São Paulo       288
# 346                                    NaN  Pacaembu  São Paulo       390
# 350                Praça Sílvio de Almeida  Pacaembu  São Paulo       550
# ...                                    ...       ...        ...       ...
# 9928                             Rua Bauru  Pacaembu  São Paulo       434
# 9954                          Rua Bragança  Pacaembu  São Paulo       285
# 9964                             Rua Bauru  Pacaembu  São Paulo       439
# 9990                          Rua Bragança  Pacaembu  São Paulo       285
# 10000                            Rua Bauru  Pacaembu  São Paulo       439
#
#        Quartos  Banheiros  Vagas                                  Valor
# ...

# %%
#fazendo a seleção por agrupamento dos bairros

dados.groupby('Bairro').mean()
# Out:
#                      Metragem   Quartos  Banheiros     Vagas
# Bairro
# Aclimação          253.056818  3.318182   3.079545  2.909091
# Alto da Boa Vista  418.875000  4.125000   5.125000  4.625000
# Alto da Lapa       294.337209  3.151163   3.790698  3.906977
# Alto da Mooca      270.050000  3.300000   2.600000  3.650000
# Alto de Pinheiros  433.444988  3.938875   4.838631  5.004890
# ...                       ...       ...        ...       ...
# Vila Água Funda    152.200000  2.600000   2.200000  2.600000
# Água Branca        191.000000  3.153846   3.076923  2.461538
# Água Fria          165.416667  2.833333   3.416667  2.500000
# Água Funda         139.000000  3.000000   2.500000  2.000000
# Água Rasa          340.250000  3.500000   3.250000  5.250000
#
# [701 rows x 4 columns]

# %% [markdown]
# #Exercício 3

# %%
ruas = dados["Rua"].value_counts()

# %%
# não entendo ainda de análises e plotagens de gráficos mas na documentação existem vários e eu coloquei esses 2 sendo tipo box e tipo hist

#gráfico em caixas
ruas.head(10).plot.box()

# %%
#tipo histograma epresentação da distribuição de dados. 
#Esta função agrupa os valores de todas as séries no DataFrame em bins e desenha todos os bins em um matplotlib.axes.Axes. 

ruas.head(10).plot.hist()

# %% [markdown]
# # Exercício 4

# %%
#achei que utilizando o describe no valor também iria exibir algo porém não aparece!!!
dados[["Metragem", "Quartos", "Valor"]].describe()
# Out:
#             Metragem       Quartos
# count   10008.000000  10008.000000
# mean      442.300659      3.483114
# std      7515.379389      1.064200
# min        10.000000      1.000000
# 25%       173.000000      3.000000
# 50%       290.000000      3.000000
# 75%       460.250000      4.000000
# max    750000.000000     16.000000

# %% [markdown]
# # Exercício 5

# %%
#tentei fazer de forma normal sem nenhum método apenas fazendo a comparação com == como no caso da aula por um tipo nulo ou não preenchido não deu certo
# tentei fazer com mais de um tipo também de resposta ao comparativo porém ele mostra tudo como falso.

bairros_sem_rua = dados["Bairro"] == "NaN, nan, NAN, nAn"
bairros_sem_rua
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
# o jeito foi fazer com o o isna

dados[dados['Rua'].isna()]
# Out:
#       Rua                            Bairro     Cidade  Metragem  Quartos  \
# 3     NaN                    Jardim Morumbi  São Paulo       310        3
# 11    NaN                  Jardim Luzitânia  São Paulo       436        4
# 31    NaN                    Parque da Lapa  São Paulo       220        4
# 56    NaN  Chácara Santo Antônio (Zona Sul)  São Paulo       190        2
# 57    NaN                    Jardim Guedala  São Paulo       650        4
# ...   ...                               ...        ...       ...      ...
# 9963  NaN                 Jardim Petrópolis  São Paulo       423        5
# 9989  NaN              Parque Alves de Lima  São Paulo       127        2
# 9991  NaN                      Vila Formosa  São Paulo       145        3
# 9995  NaN                     Jardim Leonor  São Paulo      1350        5
# 9999  NaN                 Jardim Petrópolis  São Paulo       423        5
#
#       Banheiros  Vagas         Valor
# 3             2      4    R$ 685.000
# ...
